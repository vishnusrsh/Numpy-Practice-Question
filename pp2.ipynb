# %% [markdown]
# 1

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
a=arr.copy()
arr[3]=9
print(arr)
print(a)
# Out:
# [1 2 3 9 5 6]
# [1 2 3 4 5 6]

# %% [markdown]
# 2

# %%
import numpy as np
arr=np.array([1,5,4,6,4])
a=arr.view()
arr[2]=8
print(arr)
print(a)
# Out:
# [1 5 8 6 4]
# [1 5 8 6 4]

# %% [markdown]
# 3

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
a=arr.copy()
arr[3]=9
print(arr)
print(a)
print(a.base)
print()
import numpy as np
arr=np.array([1,5,4,6,4])
a=arr.view()
arr[2]=8
print(arr)
print(a)
print(a.base)
# Out:
# [1 2 3 9 5 6]
# [1 2 3 4 5 6]
# None
#
# [1 5 8 6 4]
# [1 5 8 6 4]
# [1 5 8 6 4]

# %% [markdown]
# 4

# %%
import numpy as np
a=np.array([[1,2],[6,7]])
b=a[0].view()
b[1]=5
print(a)
print(b)
# Out:
# [[1 5]
#  [6 7]]
# [1 5]

# %% [markdown]
# 5

# %%
import numpy as np
a=np.array([[1,2],[3,4]])
b=a[0]
print(b)
print("-------------------------------")
print(b.base)
# Out:
# [1 2]
# -------------------------------
# [[1 2]
#  [3 4]]

# %% [markdown]
# 6
